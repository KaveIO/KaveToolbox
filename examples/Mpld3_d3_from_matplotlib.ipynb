# %% [markdown]
# # Matplotlib and D3js
# see: http://mpld3.github.io/quickstart.html#ipython-notebook-functions
#
# D3js uses a javascript library to create small interactive plots. It is also possible to create your own plugin widgets to display on the graph.

# %% [markdown]
# First we need to import and configure for ipython notebook

# %%
# %pylab inline
import numpy as np
import pandas as pd
import mpld3
mpld3.enable_notebook(use_http=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #let's load some practise data

# %%
import pandas.rpy.common as rcom
iris = rcom.load_data('iris')
print(iris.head())
#notice how you can mouse over, zoom and drag in these images.
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa
# /opt/anaconda/2.4.1/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: The pandas.rpy module is deprecated and will be removed in a future version. We refer to external packages like rpy2.
# See here for a guide on how to port your code to rpy2: http://pandas.pydata.org/pandas-docs/stable/r_interface.html
#   if __name__ == '__main__':

# %% [markdown]
# #notice how you can mouse over, zoom and drag these images

# %%
plt.scatter(iris["Sepal.Length"],iris["Sepal.Width"])
fig = plt.figure(figsize=(12,12))
ax=fig.add_subplot(1,1,1)
ar=pd.tools.plotting.scatter_matrix(iris,ax=ax)
# Out:
# /opt/anaconda/2.4.1/lib/python2.7/site-packages/pandas/tools/plotting.py:3303: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   "is being cleared", UserWarning)

# %% [markdown]
# # This can also integrate with seaborn

# %%
import seaborn
seaborn.pairplot(iris, hue="Species", size=2.5)

# %% [markdown]
# # aaand the standard example from the d3js website:

# %%
fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
ax.grid(color='white', linestyle='solid')

N = 50
scatter = ax.scatter(np.random.normal(size=N),
                     np.random.normal(size=N),
                     c=np.random.random(size=N),
                     s = 1000 * np.random.random(size=N),
                     alpha=0.3,
                     cmap=plt.cm.jet)

ax.set_title("D3 Scatter Plot", size=18);
