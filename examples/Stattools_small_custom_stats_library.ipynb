# %%
# %matplotlib inline
#this imports and runs the test function to show you what the output looks like
from stattools.confidencecalc import test_verticalquantile as tvq
tvq()
# Out:
# 0.242315256005 [[-0.99857861  0.99857861]]
# 0.121157628003 [[-5.99857861 -4.00142139]
#  [ 4.00142139  5.99857861]]
# 0.0215674972187 [[-30.44900413 -29.24125629]
#  [-27.30741147 -26.09966364]
#  [-24.16581882 -22.95807098]
#  [-21.02422617 -19.81647833]
#  [-17.88263351 -16.67488568]
#  [-14.74104086 -13.53329302]
#  [-11.59944821 -10.39170037]
#  [ -8.45785555  -7.25010771]
#  [ -5.3162629   -4.10851506]
#  [ -2.17467025  -0.96692241]
#  [  0.96692241   2.17467025]
#  [  4.10851506   5.3162629 ]
#  [  7.25010771   8.45785555]
#  [ 10.39170037  11.59944821]
#  [ 13.53329302  14.74104086]
#  [ 16.67488568  17.88263351]
#  [ 19.81647833  21.02422617]
#  [ 22.95807098  24.16581882]
#  [ 26.09966364  27.30741147]
#  [ 29.24125629  30.44900413]]
# 0.0276151584098 [[-30.88321624 -28.85237525]
#  [-27.66599227 -25.79614879]
#  [-24.42159235 -22.77064738]
#  [-21.12669551 -19.80118049]
#  [-17.69073475 -16.98193766]
#  [ 19.95268634  20.97252888]
#  [ 22.89183639  24.29819491]
# ...

# %%
#this imports the quantile calculation
from stattools import quantileCalc

# %%
#example with a single Gaussian:
import numpy as np
mean = 0
sigma = 10
x = np.arange(-10*np.pi,10*np.pi,0.01)
y = np.exp(-0.5*((x - mean)/sigma)**2)
qc = quantileCalc(x, y)
ylvl, intervals = qc.getquantilevertical()
#printing the y level:
print ylvl
#printing the intervals:
print intervals
# Out:
# 0.0243295722496
# [[-9.96211713  9.96211713]]

# %%
#making the ploty
qc.plot()

# %%
# %load_ext watermark
# %watermark -a KAVE -d -t -v -p numpy,pandas -g
# Out:
# KAVE 2016-09-01 17:28:38
#
# CPython 2.7.12
# IPython 4.0.1
#
# numpy 1.10.1
# pandas 0.17.1
# Git hash: e682a8ce36d019fff0ee6067182136550a222d07
